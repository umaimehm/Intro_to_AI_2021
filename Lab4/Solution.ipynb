# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn import metrics
from sklearn import preprocessing
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("data.csv", sep=",")

# %%
df.head()
# Out:
#    Var1  Var2  Var3  Var4  Var5  Var6  Result
# 0    33   206    87    81     2     4   31.34
# 1    49    14    86    50     0     9   44.26
# 2    79    72    90    62     1     5   73.94
# 3    28   173    49    67     0     5   14.93
# 4    62   189    92    47     1    20   59.60

# %% [markdown]
# Look for corelation
#
# Result = Var1*Var3-Var6+30*Var5) + Var1+2*Var3)/100
#
# Var2 and Var4 are dummies

# %%
df.head()
# Out:
#    Var1  Var2  Var3  Var4  Var5  Var6  Result
# 0    33   206    87    81     2     4   31.34
# 1    49    14    86    50     0     9   44.26
# 2    79    72    90    62     1     5   73.94
# 3    28   173    49    67     0     5   14.93
# 4    62   189    92    47     1    20   59.60

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Var1    1000 non-null   int64
#  1   Var2    1000 non-null   int64
#  2   Var3    1000 non-null   int64
#  3   Var4    1000 non-null   int64
#  4   Var5    1000 non-null   int64
#  5   Var6    1000 non-null   int64
#  6   Result  1000 non-null   float64
# dtypes: float64(1), int64(6)
# memory usage: 54.8 KB

# %%
df.plot.scatter(x = 'Var1', y = 'Result')
# Out:
# <AxesSubplot:xlabel='Var1', ylabel='Result'>

# %%
df.plot.scatter(x = 'Var5', y = 'Result', figsize=(10,8))
# Out:
# <AxesSubplot:xlabel='Var5', ylabel='Result'>

# %%
plt.matshow(df.corr())
plt.show()

# %%
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_5d2fb_row0_col0, #T_5d2fb_row1_col1, #T_5d2fb_row2_col2, #T_5d2fb_row3_col3, #T_5d2fb_row4_col4, #T_5d2fb_row5_col5, #T_5d2fb_row6_col6 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_5d2fb_row0_col1, #T_5d2fb_row2_col3 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_5d2fb_row0_col2, #T_5d2fb_row0_col4, #T_5d2fb_row1_col5, #T_5d2fb_row2_col0, #T_5d2fb_row3_col4, #T_5d2fb_row3_col5, #T_5d2fb_row5_col1, #T_5d2fb_row5_col3, #T_5d2fb_row5_col6 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_5d2fb_row0_col3, #T_5d2fb_row5_col4 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_5d2fb_row0_col5, #T_5d2fb_row6_col1 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_5d2fb_row0_col6 {
#   background-color: #df634e;
#   color: #f1f1f1;
# }
# #T_5d2fb_row1_col0 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_5d2fb_row1_col2, #T_5d2fb_row5_col2 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_5d2fb_row1_col3 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_5d2fb_row1_col4 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_5d2fb_row1_col6, #T_5d2fb_row4_col6 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_5d2fb_row2_col1, #T_5d2fb_row2_col5 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_5d2fb_row2_col4, #T_5d2fb_row4_col0, #T_5d2fb_row4_col3 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_5d2fb_row2_col6 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_5d2fb_row3_col0, #T_5d2fb_row5_col0 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_5d2fb_row3_col1 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_5d2fb_row3_col2, #T_5d2fb_row6_col3 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_5d2fb_row3_col6, #T_5d2fb_row6_col4 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_5d2fb_row4_col1 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_5d2fb_row4_col2, #T_5d2fb_row6_col5 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_5d2fb_row4_col5 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_5d2fb_row6_col0 {
#   background-color: #dd5f4b;
#   color: #f1f1f1;
# }
# #T_5d2fb_row6_col2 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# </style>
# <table id="T_5d2fb_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Var1</th>
#       <th class="col_heading level0 col1" >Var2</th>
#       <th class="col_heading level0 col2" >Var3</th>
#       <th class="col_heading level0 col3" >Var4</th>
#       <th class="col_heading level0 col4" >Var5</th>
#       <th class="col_heading level0 col5" >Var6</th>
#       <th class="col_heading level0 col6" >Result</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5d2fb_level0_row0" class="row_heading level0 row0" >Var1</th>
#       <td id="T_5d2fb_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_5d2fb_row0_col1" class="data row0 col1" >0.056326</td>
#       <td id="T_5d2fb_row0_col2" class="data row0 col2" >-0.035236</td>
#       <td id="T_5d2fb_row0_col3" class="data row0 col3" >0.033317</td>
#       <td id="T_5d2fb_row0_col4" class="data row0 col4" >-0.004222</td>
#       <td id="T_5d2fb_row0_col5" class="data row0 col5" >0.029818</td>
#       <td id="T_5d2fb_row0_col6" class="data row0 col6" >0.871279</td>
#     </tr>
#     <tr>
#       <th id="T_5d2fb_level0_row1" class="row_heading level0 row1" >Var2</th>
#       <td id="T_5d2fb_row1_col0" class="data row1 col0" >0.056326</td>
#       <td id="T_5d2fb_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_5d2fb_row1_col2" class="data row1 col2" >-0.019266</td>
#       <td id="T_5d2fb_row1_col3" class="data row1 col3" >0.005555</td>
#       <td id="T_5d2fb_row1_col4" class="data row1 col4" >-0.000932</td>
#       <td id="T_5d2fb_row1_col5" class="data row1 col5" >-0.043397</td>
#       <td id="T_5d2fb_row1_col6" class="data row1 col6" >0.028140</td>
#     </tr>
#     <tr>
#       <th id="T_5d2fb_level0_row2" class="row_heading level0 row2" >Var3</th>
#       <td id="T_5d2fb_row2_col0" class="data row2 col0" >-0.035236</td>
#       <td id="T_5d2fb_row2_col1" class="data row2 col1" >-0.019266</td>
#       <td id="T_5d2fb_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_5d2fb_row2_col3" class="data row2 col3" >0.059719</td>
#       <td id="T_5d2fb_row2_col4" class="data row2 col4" >0.023266</td>
#       <td id="T_5d2fb_row2_col5" class="data row2 col5" >-0.021135</td>
#       <td id="T_5d2fb_row2_col6" class="data row2 col6" >0.397683</td>
#     </tr>
#     <tr>
#       <th id="T_5d2fb_level0_row3" class="row_heading level0 row3" >Var4</th>
#       <td id="T_5d2fb_row3_col0" class="data row3 col0" >0.033317</td>
#       <td id="T_5d2fb_row3_col1" class="data row3 col1" >0.005555</td>
#       <td id="T_5d2fb_row3_col2" class="data row3 col2" >0.059719</td>
#       <td id="T_5d2fb_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_5d2fb_row3_col4" class="data row3 col4" >-0.008156</td>
#       <td id="T_5d2fb_row3_col5" class="data row3 col5" >-0.040191</td>
#       <td id="T_5d2fb_row3_col6" class="data row3 col6" >0.053928</td>
#     </tr>
#     <tr>
#       <th id="T_5d2fb_level0_row4" class="row_heading level0 row4" >Var5</th>
#       <td id="T_5d2fb_row4_col0" class="data row4 col0" >-0.004222</td>
#       <td id="T_5d2fb_row4_col1" class="data row4 col1" >-0.000932</td>
#       <td id="T_5d2fb_row4_col2" class="data row4 col2" >0.023266</td>
#       <td id="T_5d2fb_row4_col3" class="data row4 col3" >-0.008156</td>
#       <td id="T_5d2fb_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_5d2fb_row4_col5" class="data row4 col5" >0.063654</td>
#       <td id="T_5d2fb_row4_col6" class="data row4 col6" >0.028496</td>
#     </tr>
#     <tr>
#       <th id="T_5d2fb_level0_row5" class="row_heading level0 row5" >Var6</th>
#       <td id="T_5d2fb_row5_col0" class="data row5 col0" >0.029818</td>
#       <td id="T_5d2fb_row5_col1" class="data row5 col1" >-0.043397</td>
#       <td id="T_5d2fb_row5_col2" class="data row5 col2" >-0.021135</td>
#       <td id="T_5d2fb_row5_col3" class="data row5 col3" >-0.040191</td>
#       <td id="T_5d2fb_row5_col4" class="data row5 col4" >0.063654</td>
#       <td id="T_5d2fb_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_5d2fb_row5_col6" class="data row5 col6" >0.017604</td>
#     </tr>
#     <tr>
#       <th id="T_5d2fb_level0_row6" class="row_heading level0 row6" >Result</th>
#       <td id="T_5d2fb_row6_col0" class="data row6 col0" >0.871279</td>
#       <td id="T_5d2fb_row6_col1" class="data row6 col1" >0.028140</td>
#       <td id="T_5d2fb_row6_col2" class="data row6 col2" >0.397683</td>
#       <td id="T_5d2fb_row6_col3" class="data row6 col3" >0.053928</td>
#       <td id="T_5d2fb_row6_col4" class="data row6 col4" >0.028496</td>
#       <td id="T_5d2fb_row6_col5" class="data row6 col5" >0.017604</td>
#       <td id="T_5d2fb_row6_col6" class="data row6 col6" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
ax1 = df.plot(kind='scatter', x='Var1', y='Result', color='r')    
ax2 = df.plot(kind='scatter', x='Var2', y='Result', color='g', ax=ax1)    
ax3 = df.plot(kind='scatter', x='Var3', y='Result', color='b', ax=ax1)

# %%
x = df.values #returns a numpy array
scaler = preprocessing.MinMaxScaler().fit(x)
x = scaler.transform(x)
df = pd.DataFrame(x)
#To keep column names do
#df[list(df.columns)] = scaler.transform(df)
#instead of line 3 and 4

# %%
df.head()
# Out:
#       0         1         2         3         4         5         6
# 0  0.33  0.980100  0.883333  0.909091  0.333333  0.173913  0.316139
# 1  0.49  0.024876  0.866667  0.439394  0.000000  0.391304  0.452153
# 2  0.79  0.313433  0.933333  0.621212  0.166667  0.217391  0.764607
# 3  0.28  0.815920  0.250000  0.696970  0.000000  0.217391  0.143384
# 4  0.62  0.895522  0.966667  0.393939  0.166667  0.869565  0.613644

# %% [markdown]
# As you can see, the different columns have different min/max values. To get a better view, lets scale the values from 0 to 1

# %%
# We can reverse the scaling whit tihs code:
x = df.values #returns a numpy array
x = scaler.inverse_transform(x)
df2 = pd.DataFrame(x)
df2.head()
# Out:
#       0      1     2     3    4     5      6
# 0  33.0  206.0  87.0  81.0  2.0   4.0  31.34
# 1  49.0   14.0  86.0  50.0  0.0   9.0  44.26
# 2  79.0   72.0  90.0  62.0  1.0   5.0  73.94
# 3  28.0  173.0  49.0  67.0  0.0   5.0  14.93
# 4  62.0  189.0  92.0  47.0  1.0  20.0  59.60

# %%
#As you can see, we still have the same corr matrix
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_9f61c_row0_col0, #T_9f61c_row1_col1, #T_9f61c_row2_col2, #T_9f61c_row3_col3, #T_9f61c_row4_col4, #T_9f61c_row5_col5, #T_9f61c_row6_col6 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_9f61c_row0_col1, #T_9f61c_row2_col3 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_9f61c_row0_col2, #T_9f61c_row0_col4, #T_9f61c_row1_col5, #T_9f61c_row2_col0, #T_9f61c_row3_col4, #T_9f61c_row3_col5, #T_9f61c_row5_col1, #T_9f61c_row5_col3, #T_9f61c_row5_col6 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_9f61c_row0_col3, #T_9f61c_row5_col4 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_9f61c_row0_col5, #T_9f61c_row6_col1 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_9f61c_row0_col6 {
#   background-color: #df634e;
#   color: #f1f1f1;
# }
# #T_9f61c_row1_col0 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_9f61c_row1_col2, #T_9f61c_row5_col2 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_9f61c_row1_col3 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_9f61c_row1_col4 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_9f61c_row1_col6, #T_9f61c_row4_col6 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_9f61c_row2_col1, #T_9f61c_row2_col5 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_9f61c_row2_col4, #T_9f61c_row4_col0, #T_9f61c_row4_col3 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_9f61c_row2_col6 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_9f61c_row3_col0, #T_9f61c_row5_col0 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_9f61c_row3_col1 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_9f61c_row3_col2, #T_9f61c_row6_col3 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_9f61c_row3_col6, #T_9f61c_row6_col4 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_9f61c_row4_col1 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_9f61c_row4_col2, #T_9f61c_row6_col5 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_9f61c_row4_col5 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_9f61c_row6_col0 {
#   background-color: #dd5f4b;
#   color: #f1f1f1;
# }
# #T_9f61c_row6_col2 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# </style>
# <table id="T_9f61c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >0</th>
#       <th class="col_heading level0 col1" >1</th>
#       <th class="col_heading level0 col2" >2</th>
#       <th class="col_heading level0 col3" >3</th>
#       <th class="col_heading level0 col4" >4</th>
#       <th class="col_heading level0 col5" >5</th>
#       <th class="col_heading level0 col6" >6</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9f61c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9f61c_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_9f61c_row0_col1" class="data row0 col1" >0.056326</td>
#       <td id="T_9f61c_row0_col2" class="data row0 col2" >-0.035236</td>
#       <td id="T_9f61c_row0_col3" class="data row0 col3" >0.033317</td>
#       <td id="T_9f61c_row0_col4" class="data row0 col4" >-0.004222</td>
#       <td id="T_9f61c_row0_col5" class="data row0 col5" >0.029818</td>
#       <td id="T_9f61c_row0_col6" class="data row0 col6" >0.871279</td>
#     </tr>
#     <tr>
#       <th id="T_9f61c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9f61c_row1_col0" class="data row1 col0" >0.056326</td>
#       <td id="T_9f61c_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_9f61c_row1_col2" class="data row1 col2" >-0.019266</td>
#       <td id="T_9f61c_row1_col3" class="data row1 col3" >0.005555</td>
#       <td id="T_9f61c_row1_col4" class="data row1 col4" >-0.000932</td>
#       <td id="T_9f61c_row1_col5" class="data row1 col5" >-0.043397</td>
#       <td id="T_9f61c_row1_col6" class="data row1 col6" >0.028140</td>
#     </tr>
#     <tr>
#       <th id="T_9f61c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9f61c_row2_col0" class="data row2 col0" >-0.035236</td>
#       <td id="T_9f61c_row2_col1" class="data row2 col1" >-0.019266</td>
#       <td id="T_9f61c_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_9f61c_row2_col3" class="data row2 col3" >0.059719</td>
#       <td id="T_9f61c_row2_col4" class="data row2 col4" >0.023266</td>
#       <td id="T_9f61c_row2_col5" class="data row2 col5" >-0.021135</td>
#       <td id="T_9f61c_row2_col6" class="data row2 col6" >0.397683</td>
#     </tr>
#     <tr>
#       <th id="T_9f61c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9f61c_row3_col0" class="data row3 col0" >0.033317</td>
#       <td id="T_9f61c_row3_col1" class="data row3 col1" >0.005555</td>
#       <td id="T_9f61c_row3_col2" class="data row3 col2" >0.059719</td>
#       <td id="T_9f61c_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_9f61c_row3_col4" class="data row3 col4" >-0.008156</td>
#       <td id="T_9f61c_row3_col5" class="data row3 col5" >-0.040191</td>
#       <td id="T_9f61c_row3_col6" class="data row3 col6" >0.053928</td>
#     </tr>
#     <tr>
#       <th id="T_9f61c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9f61c_row4_col0" class="data row4 col0" >-0.004222</td>
#       <td id="T_9f61c_row4_col1" class="data row4 col1" >-0.000932</td>
#       <td id="T_9f61c_row4_col2" class="data row4 col2" >0.023266</td>
#       <td id="T_9f61c_row4_col3" class="data row4 col3" >-0.008156</td>
#       <td id="T_9f61c_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_9f61c_row4_col5" class="data row4 col5" >0.063654</td>
#       <td id="T_9f61c_row4_col6" class="data row4 col6" >0.028496</td>
#     </tr>
#     <tr>
#       <th id="T_9f61c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9f61c_row5_col0" class="data row5 col0" >0.029818</td>
#       <td id="T_9f61c_row5_col1" class="data row5 col1" >-0.043397</td>
#       <td id="T_9f61c_row5_col2" class="data row5 col2" >-0.021135</td>
#       <td id="T_9f61c_row5_col3" class="data row5 col3" >-0.040191</td>
#       <td id="T_9f61c_row5_col4" class="data row5 col4" >0.063654</td>
#       <td id="T_9f61c_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_9f61c_row5_col6" class="data row5 col6" >0.017604</td>
#     </tr>
#     <tr>
#       <th id="T_9f61c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_9f61c_row6_col0" class="data row6 col0" >0.871279</td>
#       <td id="T_9f61c_row6_col1" class="data row6 col1" >0.028140</td>
#       <td id="T_9f61c_row6_col2" class="data row6 col2" >0.397683</td>
#       <td id="T_9f61c_row6_col3" class="data row6 col3" >0.053928</td>
#       <td id="T_9f61c_row6_col4" class="data row6 col4" >0.028496</td>
#       <td id="T_9f61c_row6_col5" class="data row6 col5" >0.017604</td>
#       <td id="T_9f61c_row6_col6" class="data row6 col6" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
corr = df2.corr()
corr.style.background_gradient(cmap='plasma')
#check out https://matplotlib.org/stable/tutorials/colors/colormaps.html for
#more color maps
# Out:
# <style type="text/css">
# #T_ae9f9_row0_col0, #T_ae9f9_row1_col1, #T_ae9f9_row2_col2, #T_ae9f9_row3_col3, #T_ae9f9_row4_col4, #T_ae9f9_row5_col5, #T_ae9f9_row6_col6 {
#   background-color: #f0f921;
#   color: #000000;
# }
# #T_ae9f9_row0_col1, #T_ae9f9_row2_col3 {
#   background-color: #3f049c;
#   color: #f1f1f1;
# }
# #T_ae9f9_row0_col2, #T_ae9f9_row0_col4, #T_ae9f9_row1_col5, #T_ae9f9_row2_col0, #T_ae9f9_row3_col4, #T_ae9f9_row3_col5, #T_ae9f9_row5_col1, #T_ae9f9_row5_col3, #T_ae9f9_row5_col6 {
#   background-color: #0d0887;
#   color: #f1f1f1;
# }
# #T_ae9f9_row0_col3, #T_ae9f9_row5_col4 {
#   background-color: #350498;
#   color: #f1f1f1;
# }
# #T_ae9f9_row0_col5, #T_ae9f9_row6_col1 {
#   background-color: #330597;
#   color: #f1f1f1;
# }
# #T_ae9f9_row0_col6 {
#   background-color: #fdc229;
#   color: #000000;
# }
# #T_ae9f9_row1_col0 {
#   background-color: #3c049b;
#   color: #f1f1f1;
# }
# #T_ae9f9_row1_col2, #T_ae9f9_row5_col2 {
#   background-color: #16078a;
#   color: #f1f1f1;
# }
# #T_ae9f9_row1_col3 {
#   background-color: #280592;
#   color: #f1f1f1;
# }
# #T_ae9f9_row1_col4 {
#   background-color: #100788;
#   color: #f1f1f1;
# }
# #T_ae9f9_row1_col6, #T_ae9f9_row4_col6 {
#   background-color: #130789;
#   color: #f1f1f1;
# }
# #T_ae9f9_row2_col1, #T_ae9f9_row2_col5 {
#   background-color: #1b068d;
#   color: #f1f1f1;
# }
# #T_ae9f9_row2_col4, #T_ae9f9_row4_col0, #T_ae9f9_row4_col3 {
#   background-color: #20068f;
#   color: #f1f1f1;
# }
# #T_ae9f9_row2_col6 {
#   background-color: #ad2793;
#   color: #f1f1f1;
# }
# #T_ae9f9_row3_col0, #T_ae9f9_row5_col0 {
#   background-color: #310597;
#   color: #f1f1f1;
# }
# #T_ae9f9_row3_col1 {
#   background-color: #2a0593;
#   color: #f1f1f1;
# }
# #T_ae9f9_row3_col2, #T_ae9f9_row6_col3 {
#   background-color: #3e049c;
#   color: #f1f1f1;
# }
# #T_ae9f9_row3_col6, #T_ae9f9_row6_col4 {
#   background-color: #240691;
#   color: #f1f1f1;
# }
# #T_ae9f9_row4_col1 {
#   background-color: #260591;
#   color: #f1f1f1;
# }
# #T_ae9f9_row4_col2, #T_ae9f9_row6_col5 {
#   background-color: #2e0595;
#   color: #f1f1f1;
# }
# #T_ae9f9_row4_col5 {
#   background-color: #43039e;
#   color: #f1f1f1;
# }
# #T_ae9f9_row6_col0 {
#   background-color: #fdc527;
#   color: #000000;
# }
# #T_ae9f9_row6_col2 {
#   background-color: #b6308b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ae9f9_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >0</th>
#       <th class="col_heading level0 col1" >1</th>
#       <th class="col_heading level0 col2" >2</th>
#       <th class="col_heading level0 col3" >3</th>
#       <th class="col_heading level0 col4" >4</th>
#       <th class="col_heading level0 col5" >5</th>
#       <th class="col_heading level0 col6" >6</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ae9f9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ae9f9_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_ae9f9_row0_col1" class="data row0 col1" >0.056326</td>
#       <td id="T_ae9f9_row0_col2" class="data row0 col2" >-0.035236</td>
#       <td id="T_ae9f9_row0_col3" class="data row0 col3" >0.033317</td>
#       <td id="T_ae9f9_row0_col4" class="data row0 col4" >-0.004222</td>
#       <td id="T_ae9f9_row0_col5" class="data row0 col5" >0.029818</td>
#       <td id="T_ae9f9_row0_col6" class="data row0 col6" >0.871279</td>
#     </tr>
#     <tr>
#       <th id="T_ae9f9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ae9f9_row1_col0" class="data row1 col0" >0.056326</td>
#       <td id="T_ae9f9_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_ae9f9_row1_col2" class="data row1 col2" >-0.019266</td>
#       <td id="T_ae9f9_row1_col3" class="data row1 col3" >0.005555</td>
#       <td id="T_ae9f9_row1_col4" class="data row1 col4" >-0.000932</td>
#       <td id="T_ae9f9_row1_col5" class="data row1 col5" >-0.043397</td>
#       <td id="T_ae9f9_row1_col6" class="data row1 col6" >0.028140</td>
#     </tr>
#     <tr>
#       <th id="T_ae9f9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ae9f9_row2_col0" class="data row2 col0" >-0.035236</td>
#       <td id="T_ae9f9_row2_col1" class="data row2 col1" >-0.019266</td>
#       <td id="T_ae9f9_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_ae9f9_row2_col3" class="data row2 col3" >0.059719</td>
#       <td id="T_ae9f9_row2_col4" class="data row2 col4" >0.023266</td>
#       <td id="T_ae9f9_row2_col5" class="data row2 col5" >-0.021135</td>
#       <td id="T_ae9f9_row2_col6" class="data row2 col6" >0.397683</td>
#     </tr>
#     <tr>
#       <th id="T_ae9f9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ae9f9_row3_col0" class="data row3 col0" >0.033317</td>
#       <td id="T_ae9f9_row3_col1" class="data row3 col1" >0.005555</td>
#       <td id="T_ae9f9_row3_col2" class="data row3 col2" >0.059719</td>
#       <td id="T_ae9f9_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_ae9f9_row3_col4" class="data row3 col4" >-0.008156</td>
#       <td id="T_ae9f9_row3_col5" class="data row3 col5" >-0.040191</td>
#       <td id="T_ae9f9_row3_col6" class="data row3 col6" >0.053928</td>
#     </tr>
#     <tr>
#       <th id="T_ae9f9_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ae9f9_row4_col0" class="data row4 col0" >-0.004222</td>
#       <td id="T_ae9f9_row4_col1" class="data row4 col1" >-0.000932</td>
#       <td id="T_ae9f9_row4_col2" class="data row4 col2" >0.023266</td>
#       <td id="T_ae9f9_row4_col3" class="data row4 col3" >-0.008156</td>
#       <td id="T_ae9f9_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_ae9f9_row4_col5" class="data row4 col5" >0.063654</td>
#       <td id="T_ae9f9_row4_col6" class="data row4 col6" >0.028496</td>
#     </tr>
#     <tr>
#       <th id="T_ae9f9_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ae9f9_row5_col0" class="data row5 col0" >0.029818</td>
#       <td id="T_ae9f9_row5_col1" class="data row5 col1" >-0.043397</td>
#       <td id="T_ae9f9_row5_col2" class="data row5 col2" >-0.021135</td>
#       <td id="T_ae9f9_row5_col3" class="data row5 col3" >-0.040191</td>
#       <td id="T_ae9f9_row5_col4" class="data row5 col4" >0.063654</td>
#       <td id="T_ae9f9_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_ae9f9_row5_col6" class="data row5 col6" >0.017604</td>
#     </tr>
#     <tr>
#       <th id="T_ae9f9_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ae9f9_row6_col0" class="data row6 col0" >0.871279</td>
#       <td id="T_ae9f9_row6_col1" class="data row6 col1" >0.028140</td>
#       <td id="T_ae9f9_row6_col2" class="data row6 col2" >0.397683</td>
#       <td id="T_ae9f9_row6_col3" class="data row6 col3" >0.053928</td>
#       <td id="T_ae9f9_row6_col4" class="data row6 col4" >0.028496</td>
#       <td id="T_ae9f9_row6_col5" class="data row6 col5" >0.017604</td>
#       <td id="T_ae9f9_row6_col6" class="data row6 col6" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# And all variabels have the same scale.

# %%
ax1 = df.plot(kind='scatter', x=0, y=6, color='r')    
ax2 = df.plot(kind='scatter', x=1, y=6, color='g', ax=ax1)    
ax3 = df.plot(kind='scatter', x=2, y=6, color='b', ax=ax1)

# %% [markdown]
# Lets automate plotting for all columns in the set

# %%
#Scatterplot all columns against last column
fig, ax = plt.subplots(df.shape[1]-1, figsize=(15, 15)) #Figsize ( lenght, height )
for i in range(df.shape[1]-1):  
    
    ax[i].scatter(x = df[i], y = df[6])
    ax[i].set_xlabel("Column " + str(i))
    ax[i].set_ylabel("Y")
fig.tight_layout()
plt.show()

# %% [markdown]
# Make train and test set
# We will generate 1000 rows for the lab

# %%
# We can reverse the scaling whit tihs code:
x = df.values #returns a numpy array
x = scaler.inverse_transform(x)
df = pd.DataFrame(x)
df.head()
# Out:
#       0      1     2     3    4     5      6
# 0  33.0  206.0  87.0  81.0  2.0   4.0  31.34
# 1  49.0   14.0  86.0  50.0  0.0   9.0  44.26
# 2  79.0   72.0  90.0  62.0  1.0   5.0  73.94
# 3  28.0  173.0  49.0  67.0  0.0   5.0  14.93
# 4  62.0  189.0  92.0  47.0  1.0  20.0  59.60

# %% [markdown]
# # Train a model
#
# Looks like Var1 and maybe Var3 is the most important, but lets check.

# %%
# Exctract Var1 and result from the dataset
X = pd.DataFrame(df[0]) #Var1
y = pd.DataFrame(df[6]) #Result

# %%
#Now, split the set in training and testing set
#test_size = 0.33 tell the function that 1/3 of values should be put in test arrat
#Random state is a variable that seeds the random generator. In that way
#you'll get the same training and testing set each run
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
linear_regressor = LinearRegression()  # create object for the class
linear_regressor.fit(X_train, y_train)  # perform linear regression
Y_pred = linear_regressor.predict(X_train)  # make predictions

# %%
plt.scatter(X_train, y_train)
plt.plot(X_train, Y_pred, color='red')
plt.show()
print( "MSE = "+str(metrics.mean_squared_error(y_train,Y_pred)))
# Out:
# MSE = 116.45444051948108

# %%
Y_pred = linear_regressor.predict(X_test)  # Predict the model on X_test
plt.scatter(X_test, y_test)
plt.plot(X_test, Y_pred, color='red')
plt.show()
print( "MSE = "+str(metrics.mean_squared_error(y_test,Y_pred)))
# Out:
# MSE = 99.55992955525117

# %% [markdown]
# By chance we got a lower MSE on the test set then on training set.. The lower
# MSE is, the more accurate is the model.

# %% [markdown]
# ## Splitting your sets into training and testing is important so you can verify your model on "unseen" data

# %%
df[7] = df[0]*df[2]

# %%
X = pd.DataFrame(df[7])
Y = pd.DataFrame(df[6])
#linear_regressor = LinearRegression()  # create object for the class
linear_regressor.fit(X, Y)  # perform linear regression
Y_pred = linear_regressor.predict(X)  # make predictions
plt.scatter(X, Y)
plt.plot(X, Y_pred, color='red')
plt.show()
print( "MSE = "+str(metrics.mean_squared_error(Y,Y_pred)))
# Out:
# MSE = 0.4218388098514433

# %% [markdown]
# ## MSE = 0.4 is very low, so unless we have overfitted, we have a linear dataset, and can use Var1 and Var3 to make good predictions

# %%
#  Lets manually check with the first row from data_test.csv
linear_regressor.predict([[95*63]]) #Expected output = 62.46
# Out:
# array([[62.93803549]])

# %% [markdown]
# Looks like we have a good fit.
# Lets import the test set and check some more

# %%
df2 = pd.read_csv("data_test.csv", sep=",") #Read testset into df2
df2.head()
# Out:
#    Var1  Var2  Var3  Var4  Var5  Var6  Result
# 0    18   205    85    34     6    17   18.81
# 1    85    18    91    64     6     4   81.78
# 2    94   164    43    39     2     9   42.73
# 3    86   189    37    21     4    22   34.40
# 4    68    16    94    33     0     3   66.45

# %%
df.head()
# Out:
#       0      1     2     3    4     5      6       7
# 0  33.0  206.0  87.0  81.0  2.0   4.0  31.34  2871.0
# 1  49.0   14.0  86.0  50.0  0.0   9.0  44.26  4214.0
# 2  79.0   72.0  90.0  62.0  1.0   5.0  73.94  7110.0
# 3  28.0  173.0  49.0  67.0  0.0   5.0  14.93  1372.0
# 4  62.0  189.0  92.0  47.0  1.0  20.0  59.60  5704.0

# %%
#Make a new column for Var1 * Var3
df2["Combined"] = df2["Var1"]*df2["Var3"]
#Set X to the combined set
X = pd.DataFrame(df2["Combined"])
#Y to result
Y = pd.DataFrame(df2["Result"])
#And make sets for Var1 and Var2
X1 = pd.DataFrame(df2["Var1"])
X2 = pd.DataFrame(df2["Var3"])

#And lets do the same for the test set
Xt = pd.DataFrame(df[7])
X1t = pd.DataFrame(df[0])
X2t = pd.DataFrame(df[2])
Yt = pd.DataFrame(df[6])
#Put the data in list, so we can test the different sets in a for loop
dataSet = [X,X1,X2]
trainingSet = [Xt,X1t,X2t]

# %%
#linear_regressor = LinearRegression()  # create object for the class
linear_regressor.fit(X, Y)
Y_pred = linear_regressor.predict(X)  # make predictions
plt.scatter(X, Y)
plt.plot(X, Y_pred, color='red')
plt.show()

# %%
fig, ax = plt.subplots(3, figsize=(15, 15)) #Figsize ( lenght, height )
models = [] #List to save the different model for later use
caps = ["Var1*Var3", "Var1", "Var3"] #Caption for the plots
MSE = [] #list to save mean square error
for i in range(3):  
    linear_regressor = LinearRegression()  # create object for the class
    linear_regressor.fit(trainingSet[i], Yt)  # perform linear regression
    Y_pred = linear_regressor.predict(dataSet[i])  # make predictions
    ax[i].scatter(dataSet[i], Y) #Plot blue dots from test set
    ax[i].plot(dataSet[i], Y_pred, color='red') #Plot predicted from train
    err=metrics.mean_squared_error(Y,Y_pred)
    ax[i].set_xlabel(caps[i] + " MSE = " +str(err )) #Set caption
    ax[i].set_ylabel("Y") #Set y lable
    MSE.append(err) #Calculate and save mse for model
    models.append(linear_regressor) #Save
fig.tight_layout()
plt.show()

# %% [markdown]
# Lets test with some values from a external dataset
#
# Var1 = 79
#
# Var2 = 135
# Var3 = 36
# Var4 = 62
# Var5 = 6
# Var6 = 14
# Result = 31.61

# %%
#Var1 * Var3
v1=models[0].predict([[79*36]])
#Var 1
v2=models[1].predict([[79]])
#Var3
v3=models[1].predict([[36]])

# %%
print(f"Prediction with:\nVar1*Var3 = {v1[0][0]}\nVar1 = {v2[0][0]}\nVar3 = {v3[0][0]}")
print("Correct value = 31.61")
# Out:
# Prediction with:
# Var1*Var3 = 30.950911117701498
# Var1 = 53.80770756065712
# Var3 = 25.79824010435377
# Correct value = 31.61

# %%
MSE
# Out:
# [0.5152480718931592, 134.20940310940424, 418.0531555252962]

# %%
import pickle

# %%
# save the model to disk
filename = 'finalized_model.sav'
pickle.dump(models[0], open(filename, 'wb'))

# %%
loaded_model = pickle.load(open(filename, 'rb'))
loaded_model.predict([[79*36]])
# Out:
# array([[30.95091112]])
